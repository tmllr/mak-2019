# %% [markdown]
# # MAK DRAFT HELPER 2019

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Batters

# %%
batters = pd.read_csv('./FantasyPros_2019_Projections_H.csv')

# %% [markdown]
# Fantasy Pros (fantasypros.com) produces an aggregated expert projections for each player across several key stats. No need to reinvent the wheel like Nate Silver did in his book with inefficient models - we just take what the experts project (using their models) and look at their consensus.

# %%
batters.head()
# Out:
#           Player Team Positions     AB      R    HR    RBI    SB    AVG  \
# 0     Mike Trout  LAA     CF,DH  509.0  112.0  38.0   95.0  23.0  0.307
# 1   Mookie Betts  BOS     CF,RF  586.0  115.0  30.0   91.0  26.0  0.305
# 2   Jose Ramirez  CLE     2B,3B  567.0  100.0  30.0   96.0  24.0  0.286
# 3  Nolan Arenado  COL        3B  584.0   98.0  37.0  111.0   2.0  0.291
# 4  J.D. Martinez  BOS  LF,RF,DH  543.0   97.0  39.0  114.0   4.0  0.303
#
#      OBP      H    2B   3B     BB     SO    SLG    OPS  Own
# 0  0.438  156.0  28.0  4.0  119.0  127.0  0.606  1.044  99%
# 1  0.385  179.0  43.0  4.0   76.0   93.0  0.544  0.929  99%
# 2  0.374  162.0  41.0  4.0   80.0   76.0  0.534  0.908  99%
# 3  0.362  170.0  38.0  4.0   65.0  115.0  0.559  0.921  99%
# 4  0.376  164.0  33.0  2.0   63.0  148.0  0.587  0.962  99%

# %%
del batters['OBP']
del batters['2B']
del batters['3B']
del batters['SLG']
del batters['OPS']

# %%
batters = batters[batters['AB'] >= 200]

# %%
batters['BB/KO'] = batters['BB'] / batters['SO']

# %% [markdown]
# For BB/KO, we want to look at the number of walks ABOVE the average BB/KO of the selection set (which is all batters projected to have over 200 AB's). This will approproately weight the average based on projected Fantasy production. We do the same with batting average.

# %%
bbko_mean = batters['BB/KO'].mean()
bbko_mean
# Out:
# 0.3989026493701326

# %%
batters['BB+'] = (batters['BB/KO'] - bbko_mean) * batters['SO']

# %%
batters['AVG'] = batters['H'] / batters['AB']

# %%
avg_mean = batters['AVG'].mean()
avg_mean
# Out:
# 0.2530256240141296

# %%
batters['AVG+'] = (batters['AVG'] - avg_mean) * batters['AB']

# %% [markdown]
# For this year, I'm simply standardizing each metric to the 0-100 linear scale with 100 being the top performer for that metric and 0 being the bottom. Since the scales are different for each one, this makes sense. In the past, I've used Z scores, but it is easier to be able to mentally calculate the actual metric in some cases. It also makes sense since these stats all accumulate over the course of the season/week.

# %%
batters['AVGS'] = round( ( batters['AVG+'] - batters['AVG+'].min() ) / ( batters['AVG+'].max() - batters['AVG+'].min() ) * 100 )
batters['BBKOS'] = round( ( batters['BB+'] - batters['BB+'].min() ) / ( batters['BB+'].max() - batters['BB+'].min() ) * 100 )
batters['HRS'] = round( ( batters['HR'] - batters['HR'].min() ) / ( batters['HR'].max() - batters['HR'].min() ) * 100 )
batters['RS'] = round( ( batters['R'] - batters['R'].min() ) / ( batters['R'].max() - batters['R'].min() ) * 100 )
batters['RBIS'] = round( ( batters['RBI'] - batters['RBI'].min() ) / ( batters['RBI'].max() - batters['RBI'].min() ) * 100 )
batters['SBS'] = round( ( batters['SB'] - batters['SB'].min() ) / ( batters['SB'].max() - batters['SB'].min() ) * 100 )
batters['SCORE'] = batters['AVGS'] + batters['BBKOS'] + batters['HRS'] + batters['RS'] + batters['RBIS'] + batters['SBS']
batters['RANK'] = batters['SCORE'].rank(method='average', na_option='keep', ascending=False, pct=False)

# %%
batters.sort_values(['SCORE'], ascending=[0])[0:5]
# Out:
#           Player Team Positions     AB      R    HR    RBI    SB       AVG  \
# 0     Mike Trout  LAA     CF,DH  509.0  112.0  38.0   95.0  23.0  0.306483
# 1   Mookie Betts  BOS     CF,RF  586.0  115.0  30.0   91.0  26.0  0.305461
# 2   Jose Ramirez  CLE     2B,3B  567.0  100.0  30.0   96.0  24.0  0.285714
# 4  J.D. Martinez  BOS  LF,RF,DH  543.0   97.0  39.0  114.0   4.0  0.302026
# 9   Bryce Harper  PHI     CF,RF  517.0   98.0  34.0   99.0  11.0  0.266925
#
#        H  ...         BB+       AVG+  AVGS  BBKOS   HRS     RS   RBIS   SBS  \
# 0  156.0  ...   68.339364  27.209957  86.0  100.0  90.0   97.0   81.0  51.0
# 1  179.0  ...   38.902054  30.726984  91.0   77.0  71.0  100.0   77.0  58.0
# 2  162.0  ...   49.683399  18.534471  71.0   86.0  71.0   84.0   82.0  53.0
# 4  164.0  ...    3.962408  26.607086  85.0   50.0  93.0   81.0  100.0   9.0
# 9  138.0  ...   52.164603   7.185752  53.0   88.0  80.0   82.0   85.0  24.0
#
#    SCORE  RANK
# 0  505.0   1.0
# 1  474.0   2.0
# 2  447.0   3.0
# 4  418.0   4.0
# 9  412.0   5.0
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Pitchers

# %%
pitchers = pd.read_csv('./FantasyPros_2019_Projections_P.csv')

# %%
pitchers.head()
# Out:
#              Player Team Positions     IP      K     W   SV   ERA  WHIP    ER  \
# 0      Max Scherzer  WSH        SP  206.9  269.0  16.0  0.0  2.94  1.01  68.0
# 1        Chris Sale  BOS        SP  186.0  249.0  15.0  0.0  2.68  0.97  55.0
# 2      Jacob deGrom  NYM        SP  207.6  248.0  15.0  0.0  2.75  1.05  63.0
# 3  Justin Verlander  HOU        SP  201.1  245.0  16.0  0.0  3.17  1.05  71.0
# 4      Corey Kluber  CLE        SP  206.9  221.0  16.0  0.0  3.23  1.07  74.0
#
#        H    BB    HR     G    GS    L   CG  Own
# 0  154.0  55.0  25.0  32.0  32.0  8.0  2.0  99%
# 1  141.0  40.0  19.0  30.0  30.0  6.0  0.0  99%
# 2  166.0  52.0  20.0  32.0  32.0  9.0  1.0  99%
# 3  159.0  51.0  27.0  32.0  31.0  8.0  1.0  99%
# 4  180.0  43.0  24.0  32.0  32.0  8.0  3.0  99%

# %% [markdown]
# We score on Holds+SVS, so I need to bring that stat in from elsewhere

# %%
holds = pd.read_csv('./cbs_P_Scoring.csv', header=1)

# %%
holds.head()
# Out:
#                    Avail                      Player  MLB Eligible    INN  \
# 0      Low hanging fruit      Max Scherzer SP | WAS   0.0        P  206.3
# 1          Team Gorgeous       Jacob deGrom SP | NYM  0.0        P  197.3
# 2  Rakuten Golden Eagles        Chris Sale SP | BOS   0.0        P  166.7
# 3     stroke me strokeme  Justin Verlander SP | HOU   0.0        P  198.3
# 4       Tommy's Shinebox       Corey Kluber SP | CLE  0.0        P  205.0
#
#     ERA  WHIP      K    S   HD   W-L    BB      H    ER  Rank  Unnamed: 15
# 0  2.97  1.05  255.0  0.0  0.0  10.0  57.0  159.0  68.0   7.0          NaN
# 1  2.46  1.09  221.0  0.0  0.0   6.0  51.0  164.0  54.0  14.0          NaN
# 2  2.70  1.05  214.0  0.0  0.0   9.0  38.0  137.0  50.0  15.0          NaN
# 3  3.04  1.11  245.0  0.0  0.0  11.0  58.0  163.0  67.0  20.0          NaN
# 4  3.29  1.14  229.0  0.0  0.0  12.0  47.0  187.0  75.0  22.0          NaN

# %%
holds = holds[ holds['HD'] > 0 ]
holds['Name'] = holds['Player']
holds['Player'] = holds['Name'].str.extract(r'^(.+ .+) \w+ \|', expand=False)
holds['Team'] = holds['Name'].str.extract(r'\|\s(\w\w\w|\w\w)(?:\s|$)', expand=False)
holds = holds[ ['Player', 'Team', 'HD'] ]
holds = holds.replace('WAS', 'WSH')
holds = holds.replace('CHW', 'CWS')
holds.head()
# Out:
#              Player Team   HD
# 14       Edwin Diaz  NYM  3.0
# 16    Blake Treinen  OAK  3.0
# 18    Craig Kimbrel  BOS  3.0
# 22  Aroldis Chapman  NYY  3.0
# 28    Kenley Jansen  LAD  3.0

# %%
pitchers = pitchers.merge(holds, on=['Player', 'Team'], how='left')

# %%
pitchers[pitchers['Player'].isnull()].head()
# Out:
#     Player Team Positions  IP   K   W  SV  ERA  WHIP  ER   H  BB  HR   G  GS  \
# 883    NaN  NaN       NaN NaN NaN NaN NaN  NaN   NaN NaN NaN NaN NaN NaN NaN
# 884    NaN  NaN       NaN NaN NaN NaN NaN  NaN   NaN NaN NaN NaN NaN NaN NaN
#
#       L  CG  Own  HD
# 883 NaN NaN  NaN NaN
# 884 NaN NaN  NaN NaN

# %%
del pitchers['HR']
del pitchers['G']
del pitchers['GS']
del pitchers['CG']

# %%
pitchers = pitchers[pitchers['IP'] >= 40]

# %%
pitchers['ERA'] = pitchers['ER'] / pitchers['IP'] * 9
era_mean = pitchers['ERA'].mean()
pitchers['ERA+'] = ( era_mean - pitchers['ERA'] ) * pitchers['IP']

# %%
pitchers['WHIP'] = (pitchers['BB'] + pitchers['H']) / pitchers['IP']
whip_mean = pitchers['WHIP'].mean()
pitchers['WHIP+'] = ( whip_mean -  pitchers['WHIP'] ) * pitchers['IP']

# %%
pitchers['W-L'] = pitchers['W'] - pitchers['L']

# %%
pitchers['HD'].fillna(0, inplace=True)
pitchers['SV+HD'] = pitchers['SV'] + pitchers['HD']

# %%
pitchers['ERAS'] = round( ( pitchers['ERA+'] - pitchers['ERA+'].min() ) / ( pitchers['ERA+'].max() - pitchers['ERA+'].min() ) * 100 )
pitchers['WHIPS'] = round( ( pitchers['WHIP+'] - pitchers['WHIP+'].min() ) / ( pitchers['WHIP+'].max() - pitchers['WHIP+'].min() ) * 100 )
pitchers['KS'] = round( ( pitchers['K'] - pitchers['K'].min() ) / ( pitchers['K'].max() - pitchers['K'].min() ) * 100 )
pitchers['SV+HDS'] = round( ( pitchers['SV+HD'] - pitchers['SV+HD'].min() ) / ( pitchers['SV+HD'].max() - pitchers['SV+HD'].min() ) * 100 )
pitchers['WLS'] = round( ( pitchers['W-L'] - pitchers['W-L'].min() ) / ( pitchers['W-L'].max() - pitchers['W-L'].min() ) * 100 )
pitchers['SCORE'] = pitchers['ERAS'] + pitchers['WHIPS'] + pitchers['KS'] + pitchers['SV+HDS'] + pitchers['WLS']
pitchers['RANK'] = pitchers['SCORE'].rank(method='average', na_option='keep', ascending=False, pct=False)

# %%
pitchers.sort_values(['SCORE'], ascending=[0])[0:5]
# Out:
#              Player Team Positions     IP      K     W   SV       ERA  \
# 1        Chris Sale  BOS        SP  186.0  249.0  15.0  0.0  2.661290
# 0      Max Scherzer  WSH        SP  206.9  269.0  16.0  0.0  2.957951
# 2      Jacob deGrom  NYM        SP  207.6  248.0  15.0  0.0  2.731214
# 3  Justin Verlander  HOU        SP  201.1  245.0  16.0  0.0  3.177524
# 4      Corey Kluber  CLE        SP  206.9  221.0  16.0  0.0  3.218946
#
#        WHIP    ER  ...       WHIP+  W-L  SV+HD   ERAS  WHIPS     KS  SV+HDS  \
# 1  0.973118  55.0  ...   74.788030  9.0    0.0   97.0   99.0   92.0     0.0
# 0  1.010150  68.0  ...   75.529803  8.0    0.0   92.0  100.0  100.0     0.0
# 2  1.050096  63.0  ...   67.492446  6.0    0.0  100.0   94.0   91.0     0.0
# 3  1.044257  71.0  ...   66.553617  8.0    0.0   84.0   94.0   90.0     0.0
# 4  1.077815  74.0  ...   61.529803  8.0    0.0   84.0   90.0   80.0     0.0
#
#      WLS  SCORE  RANK
# 1  100.0  388.0   1.0
# 0   93.0  385.0   2.0
# 2   79.0  364.0   3.0
# 3   93.0  361.0   4.0
# 4   93.0  347.0   5.0
#
# [5 rows x 26 columns]

# %% [markdown]
# ## Combining Pitchers and Batters

# %% [markdown]
# Since we score across five pitching and six hitting categories, with the weekly winners determined by the highest aggregate scores in each category, it makes sense to compare score weight of batters vs. pitchers
#
# For the last couple of seasons, I've tried to "break the game" by focusing only on all the pitching categories plus two batting categories (AVG and BBKO) where there are batters generally available with high performance at a low cost. This has had mixed results, as the league adjusted accordingly.

# %%
batters_lim = batters[ ['Player', 'Team', 'Positions', 'AVGS', 'BBKOS', 'HRS', 'RS', 'RBIS', 'SBS', 'SCORE'] ]
pitchers_lim = pitchers[ ['Player', 'Team', 'Positions', 'ERAS', 'WHIPS', 'KS', 'SV+HDS', 'WLS', 'SCORE'] ]
all_players = pd.concat([batters_lim, pitchers_lim],sort=True)
all_players['RANK'] = all_players['SCORE'].rank(method='average', na_option='keep', ascending=False, pct=False)
all_players = all_players.sort_values(['SCORE'], ascending=[0])

# %%
all_players.head(25)
# Out:
#      AVGS  BBKOS   ERAS    HRS     KS             Player Positions   RBIS  \
# 0    86.0  100.0    NaN   90.0    NaN         Mike Trout     CF,DH   81.0
# 1    91.0   77.0    NaN   71.0    NaN       Mookie Betts     CF,RF   77.0
# 2    71.0   86.0    NaN   71.0    NaN       Jose Ramirez     2B,3B   82.0
# 4    85.0   50.0    NaN   93.0    NaN      J.D. Martinez  LF,RF,DH  100.0
# 9    53.0   88.0    NaN   80.0    NaN       Bryce Harper     CF,RF   85.0
# 3    77.0   62.0    NaN   88.0    NaN      Nolan Arenado        3B   97.0
# 5    85.0   61.0    NaN   63.0    NaN   Christian Yelich  LF,CF,RF   78.0
# 11   71.0   80.0    NaN   63.0    NaN       Alex Bregman     3B,SS   78.0
# 8    69.0   66.0    NaN   68.0    NaN   Francisco Lindor        SS   69.0
# 6    68.0   52.0    NaN   41.0    NaN        Trea Turner        SS   55.0
# 10  100.0   65.0    NaN   39.0    NaN        Jose Altuve        2B   64.0
# 23   72.0   80.0    NaN   68.0    NaN          Juan Soto        LF   80.0
# 1     NaN    NaN   97.0    NaN   92.0         Chris Sale        SP    NaN
# 0     NaN    NaN   92.0    NaN  100.0       Max Scherzer        SP    NaN
# 17   68.0   68.0    NaN   68.0    NaN   Paul Goldschmidt        1B   79.0
# 13   51.0   63.0    NaN   90.0    NaN        Aaron Judge     RF,DH   79.0
# 15   84.0   66.0    NaN   61.0    NaN    Freddie Freeman        1B   78.0
# 22   65.0   79.0    NaN   66.0    NaN      Anthony Rizzo        1B   84.0
# 12   70.0   62.0    NaN   76.0    NaN      Manny Machado     3B,SS   80.0
# 7    64.0   42.0    NaN   71.0    NaN       Ronald Acuna     LF,CF   72.0
# 16   53.0   44.0    NaN  100.0    NaN  Giancarlo Stanton  LF,RF,DH   94.0
# 19   79.0   51.0    NaN   66.0    NaN   Charlie Blackmon        CF   62.0
# 20   70.0   68.0    NaN   41.0    NaN  Andrew Benintendi     LF,CF   68.0
# 27   38.0   67.0    NaN   85.0    NaN       Rhys Hoskins     1B,LF   89.0
# 2     NaN    NaN  100.0    NaN   91.0       Jacob deGrom        SP    NaN
#
#        RS    SBS  SCORE  SV+HDS Team  WHIPS    WLS  RANK
# 0    97.0   51.0  505.0     NaN  LAA    NaN    NaN   1.0
# 1   100.0   58.0  474.0     NaN  BOS    NaN    NaN   2.0
# 2    84.0   53.0  447.0     NaN  CLE    NaN    NaN   3.0
# 4    81.0    9.0  418.0     NaN  BOS    NaN    NaN   4.0
# 9    82.0   24.0  412.0     NaN  PHI    NaN    NaN   5.0
# 3    82.0    4.0  410.0     NaN  COL    NaN    NaN   6.5
# 5    85.0   38.0  410.0     NaN  MIL    NaN    NaN   6.5
# 11   82.0   24.0  398.0     NaN  HOU    NaN    NaN   8.0
# 8    85.0   40.0  397.0     NaN  CLE    NaN    NaN   9.0
# 6    79.0  100.0  395.0     NaN  WSH    NaN    NaN  10.5
# 10   78.0   49.0  395.0     NaN  HOU    NaN    NaN  10.5
# 23   77.0   16.0  393.0     NaN  WSH    NaN    NaN  12.0
# 1     NaN    NaN  388.0     0.0  BOS   99.0  100.0  13.0
# 0     NaN    NaN  385.0     0.0  WSH  100.0   93.0  14.0
# 17   79.0   22.0  384.0     NaN  STL    NaN    NaN  15.0
# 13   84.0   16.0  383.0     NaN  NYY    NaN    NaN  16.0
# 15   75.0   18.0  382.0     NaN  ATL    NaN    NaN  17.0
# 22   69.0   16.0  379.0     NaN  CHC    NaN    NaN  19.5
# 12   69.0   22.0  379.0     NaN   SD    NaN    NaN  19.5
# 7    79.0   51.0  379.0     NaN  ATL    NaN    NaN  19.5
# 16   81.0    7.0  379.0     NaN  NYY    NaN    NaN  19.5
# 19   91.0   27.0  376.0     NaN  COL    NaN    NaN  22.0
# 20   82.0   42.0  371.0     NaN  BOS    NaN    NaN  23.0
# 27   75.0   11.0  365.0     NaN  PHI    NaN    NaN  24.0
# 2     NaN    NaN  364.0     0.0  NYM   94.0   79.0  25.0

# %% [markdown]
# ## Join on list of currently drafted players

# %%
draft = pd.read_csv('./results.csv', header=1)
draft.head()
# Out:
#   Pick                           Team                  Player  \
# 0    1  MitchMoreland'sBattingAverage     Mike Trout CF | LAA
# 1    2               Tommy's Shinebox  Mookie Betts RF | BOS
# 2    3                La Flama Blanca   Jose Altuve 2B | HOU
# 3    4              Low hanging fruit  Max Scherzer SP | WAS
# 4    5                       Foul_Tip  Nolan Arenado 3B | COL
#
#           Elapsed Time  Unnamed: 4
# 0                  NaN         NaN
# 1  8 hrs 29 min 27 sec         NaN
# 2        32 min 24 sec         NaN
# 3         2 min 59 sec         NaN
# 4        57 min 17 sec         NaN

# %%
draft = draft[ ['Player', 'Team'] ]
draft['Name'] = draft['Player']
draft['Owner'] = draft['Team']
draft = draft[ draft['Player'] != 'Player' ]
draft['Player'] = draft['Name'].str.extract(r'^(.+ .+) \w+ \|', expand=False)
draft['Team'] = draft['Name'].str.extract(r'\|\s(\w\w\w|\w\w)(?:\s|$)', expand=False)
draft = draft.dropna()

# %%
draft = draft.replace('WAS', 'WSH')
draft = draft.replace('CHW', 'CWS')

# %%
draft.head()
# Out:
#           Player Team                    Name                          Owner
# 0     Mike Trout  LAA     Mike Trout CF | LAA  MitchMoreland'sBattingAverage
# 1   Mookie Betts  BOS  Mookie Betts RF | BOS                Tommy's Shinebox
# 2    Jose Altuve  HOU   Jose Altuve 2B | HOU                 La Flama Blanca
# 3   Max Scherzer  WSH  Max Scherzer SP | WAS               Low hanging fruit
# 4  Nolan Arenado  COL  Nolan Arenado 3B | COL                       Foul_Tip

# %%
draft.loc[draft.Player == 'Craig Kimbrel', 'Team'] = np.nan
all_players_owners = all_players.merge(draft, on=['Player', 'Team'], how='outer')

# %%
all_players_owners.head()
# Out:
#    AVGS  BBKOS  ERAS   HRS  KS         Player Positions   RBIS     RS   SBS  \
# 0  86.0  100.0   NaN  90.0 NaN     Mike Trout     CF,DH   81.0   97.0  51.0
# 1  91.0   77.0   NaN  71.0 NaN   Mookie Betts     CF,RF   77.0  100.0  58.0
# 2  71.0   86.0   NaN  71.0 NaN   Jose Ramirez     2B,3B   82.0   84.0  53.0
# 3  85.0   50.0   NaN  93.0 NaN  J.D. Martinez  LF,RF,DH  100.0   81.0   9.0
# 4  53.0   88.0   NaN  80.0 NaN   Bryce Harper     CF,RF   85.0   82.0  24.0
#
#    SCORE  SV+HDS Team  WHIPS  WLS  RANK                            Name  \
# 0  505.0     NaN  LAA    NaN  NaN   1.0             Mike Trout CF | LAA
# 1  474.0     NaN  BOS    NaN  NaN   2.0          Mookie Betts RF | BOS
# 2  447.0     NaN  CLE    NaN  NaN   3.0  Jose Ramirez 3B | CLE (Keeper)
# 3  418.0     NaN  BOS    NaN  NaN   4.0         J.D. Martinez DH | BOS
# 4  412.0     NaN  PHI    NaN  NaN   5.0          Bryce Harper RF | PHI
#
#                            Owner
# 0  MitchMoreland'sBattingAverage
# 1               Tommy's Shinebox
# 2      BC-Mizusawa South Monkeyz
# 3             stroke me strokeme
# 4                 Regular Rubens

# %% [markdown]
# Ensure all players merged. Cross fingers that there aren't any players on the same team with the same name. That would be weird though. This takes advatage of the characterisitics of an outer join.

# %%
all_players_owners[all_players_owners['Player'].isnull()].head()
# Out:
# Empty DataFrame
# Columns: [AVGS, BBKOS, ERAS, HRS, KS, Player, Positions, RBIS, RS, SBS, SCORE, SV+HDS, Team, WHIPS, WLS, RANK, Name, Owner]
# Index: []

# %%
all_players_owners[all_players_owners['Positions'].isnull()].head()
# Out:
# Empty DataFrame
# Columns: [AVGS, BBKOS, ERAS, HRS, KS, Player, Positions, RBIS, RS, SBS, SCORE, SV+HDS, Team, WHIPS, WLS, RANK, Name, Owner]
# Index: []

# %% [markdown]
# ## All Currently Undrafted

# %%
all_players_owners = all_players_owners[ ['Player', 'Positions', 'Team', 'SCORE', 'RANK', 'AVGS', 'BBKOS', 'HRS', 'RBIS', 'RS', 'SBS', 'ERAS', 'WHIPS', 'KS', 'WLS', 'SV+HDS', 'Owner'] ]
#Manually add minors drafted
all_players_owners.loc[all_players_owners.Player == 'Vladimir Guerrero Jr.', 'Owner'] = 'Low hanging fruit'
free_agents = all_players_owners[all_players_owners['Owner'].isnull()]
del free_agents['Owner']
free_agents.head(50)
# Out:
#                    Player    Positions Team  SCORE   RANK  AVGS  BBKOS   HRS  \
# 95      Andrelton Simmons           SS  LAA  285.0   96.5  67.0   61.0  24.0
# 96              Josh Bell           1B  PIT  285.0   96.5  51.0   68.0  41.0
# 101  Seranthony Dominguez        SP,RP  PHI  281.0  102.5   NaN    NaN   NaN
# 103         Andrew Miller           RP  STL  281.0  102.5   NaN    NaN   NaN
# 105         Shohei Ohtani        SP,DH  LAA  279.0  106.5  56.0   44.0  56.0
# 108            Ryan Braun        1B,LF  MIL  278.0  110.0  51.0   47.0  49.0
# 110         Jorge Polanco           SS  MIN  278.0  110.0  57.0   50.0  32.0
# 111         Victor Robles           RF  WSH  277.0  112.0  54.0   47.0  27.0
# 113          Justin Smoak        1B,DH  TOR  276.0  114.0  33.0   58.0  63.0
# 116         Shin-Soo Choo     LF,RF,DH  TEX  275.0  116.5  44.0   63.0  44.0
# 120        Kyle Schwarber           LF  CHC  272.0  122.5  27.0   58.0  66.0
# 121         Marcus Semien           SS  OAK  272.0  122.5  41.0   51.0  39.0
# 125            Adam Eaton        LF,RF  WSH  271.0  125.5  67.0   59.0  22.0
# 128          Eloy Jimenez        LF,RF  CWS  269.0  129.0  65.0   42.0  54.0
# 130           Jake Bauers        1B,LF  CLE  267.0  131.0  31.0   59.0  39.0
# 131       Corey Dickerson        LF,DH  PIT  266.0  132.5  66.0   37.0  44.0
# 132         Adam Ottavino           RP  NYY  266.0  132.5   NaN    NaN   NaN
# 133            Max Kepler        CF,RF  MIN  265.0  134.5  36.0   61.0  46.0
# 134           Ian Desmond        1B,LF  COL  265.0  134.5  43.0   40.0  41.0
# 136          Elvis Andrus           SS  TEX  263.0  137.0  57.0   51.0  24.0
# 138         Maikel Franco           3B  PHI  262.0  138.5  45.0   51.0  56.0
# 141      Asdrubal Cabrera     2B,3B,SS  TEX  260.0  143.0  58.0   47.0  46.0
# 144       Eduardo Escobar        3B,SS  ARI  259.0  145.5  46.0   46.0  46.0
# 146          Yoan Moncada           2B  CWS  258.0  147.5  29.0   39.0  46.0
# 147             Jake Lamb           3B  ARI  258.0  147.5  31.0   54.0  49.0
# 149          Brandon Belt        1B,LF   SF  256.0  150.0  42.0   61.0  44.0
# 150           Ketel Marte        2B,SS  ARI  256.0  150.0  54.0   60.0  27.0
# 151          Chris Taylor  2B,SS,LF,CF  LAD  255.0  153.0  42.0   39.0  37.0
# 153          Yuli Gurriel     1B,3B,DH  HOU  255.0  153.0  67.0   46.0  29.0
# 154         Nick Markakis           RF  ATL  254.0  155.5  61.0   67.0  24.0
# 155    Jackie Bradley Jr.        CF,RF  BOS  254.0  155.5  34.0   44.0  39.0
# 157       Dellin Betances           RP  NYY  252.0  160.5   NaN    NaN   NaN
# 158        Austin Meadows     LF,CF,RF   TB  252.0  160.5  50.0   44.0  37.0
# 159       Jonathan Schoop           2B  MIN  252.0  160.5  48.0   30.0  56.0
# 161          Tim Anderson           SS  CWS  252.0  160.5  39.0   21.0  41.0
# 162        Randal Grichuk        CF,RF  TOR  252.0  160.5  34.0   28.0  66.0
# 166        Brian Anderson        3B,RF  MIA  250.0  166.5  49.0   50.0  32.0
# 167        Ryan Zimmerman           1B  WSH  250.0  166.5  49.0   48.0  49.0
# 168          Amed Rosario           SS  NYM  249.0  169.5  47.0   33.0  24.0
# 169             C.J. Cron        1B,DH  MIN  249.0  169.5  45.0   36.0  59.0
# 170          Kole Calhoun           RF  LAA  248.0  173.0  28.0   52.0  44.0
# 172       David Robertson           RP  PHI  248.0  173.0   NaN    NaN   NaN
# 174       Raisel Iglesias           RP  CIN  248.0  173.0   NaN    NaN   NaN
# 175           Paul DeJong           SS  STL  247.0  177.0  42.0   31.0  56.0
# 176          Jason Kipnis     2B,CF,DH  CLE  247.0  177.0  34.0   53.0  39.0
# 177          Trey Mancini        1B,LF  BAL  247.0  177.0  46.0   35.0  54.0
# 180            Wade Davis           RP  COL  245.0  182.0   NaN    NaN   NaN
# 186        Billy Hamilton           CF   KC  243.0  187.5  32.0   42.0   7.0
# 187        Chris Devenski           RP  HOU  243.0  187.5   NaN    NaN   NaN
# 188         Yonder Alonso           1B  CWS  242.0  191.5  35.0   52.0  51.0
#
#      RBIS    RS   SBS  ERAS  WHIPS    KS   WLS  SV+HDS
# 95   54.0  52.0  27.0   NaN    NaN   NaN   NaN     NaN
# 96   61.0  57.0   7.0   NaN    NaN   NaN   NaN     NaN
# 101   NaN   NaN   NaN  59.0   57.0  24.0  43.0    98.0
# 103   NaN   NaN   NaN  59.0   57.0  22.0  43.0   100.0
# 105  58.0  45.0  20.0   NaN    NaN   NaN   NaN     NaN
# 108  56.0  48.0  27.0   NaN    NaN   NaN   NaN     NaN
# 110  54.0  56.0  29.0   NaN    NaN   NaN   NaN     NaN
# 111  42.0  49.0  58.0   NaN    NaN   NaN   NaN     NaN
# 113  65.0  55.0   2.0   NaN    NaN   NaN   NaN     NaN
# 116  47.0  61.0  16.0   NaN    NaN   NaN   NaN     NaN
# 120  58.0  54.0   9.0   NaN    NaN   NaN   NaN     NaN
# 121  53.0  59.0  29.0   NaN    NaN   NaN   NaN     NaN
# 125  38.0  61.0  24.0   NaN    NaN   NaN   NaN     NaN
# 128  60.0  46.0   2.0   NaN    NaN   NaN   NaN     NaN
# 130  56.0  53.0  29.0   NaN    NaN   NaN   NaN     NaN
# 131  53.0  53.0  13.0   NaN    NaN   NaN   NaN     NaN
# 132   NaN   NaN   NaN  57.0   53.0  26.0  43.0    87.0
# 133  54.0  55.0  13.0   NaN    NaN   NaN   NaN     NaN
# 134  54.0  51.0  36.0   NaN    NaN   NaN   NaN     NaN
# 136  47.0  55.0  29.0   NaN    NaN   NaN   NaN     NaN
# 138  64.0  44.0   2.0   NaN    NaN   NaN   NaN     NaN
# 141  56.0  49.0   4.0   NaN    NaN   NaN   NaN     NaN
# 144  61.0  53.0   7.0   NaN    NaN   NaN   NaN     NaN
# 146  49.0  62.0  33.0   NaN    NaN   NaN   NaN     NaN
# 147  61.0  54.0   9.0   NaN    NaN   NaN   NaN     NaN
# 149  51.0  49.0   9.0   NaN    NaN   NaN   NaN     NaN
# 150  43.0  54.0  18.0   NaN    NaN   NaN   NaN     NaN
# 151  50.0  60.0  27.0   NaN    NaN   NaN   NaN     NaN
# 153  58.0  46.0   9.0   NaN    NaN   NaN   NaN     NaN
# 154  55.0  45.0   2.0   NaN    NaN   NaN   NaN     NaN
# 155  53.0  55.0  29.0   NaN    NaN   NaN   NaN     NaN
# 157   NaN   NaN   NaN  64.0   59.0  33.0  43.0    53.0
# 158  46.0  44.0  31.0   NaN    NaN   NaN   NaN     NaN
# 159  62.0  52.0   4.0   NaN    NaN   NaN   NaN     NaN
# 161  49.0  55.0  47.0   NaN    NaN   NaN   NaN     NaN
# 162  62.0  53.0   9.0   NaN    NaN   NaN   NaN     NaN
# 166  53.0  59.0   7.0   NaN    NaN   NaN   NaN     NaN
# 167  58.0  42.0   4.0   NaN    NaN   NaN   NaN     NaN
# 168  42.0  52.0  51.0   NaN    NaN   NaN   NaN     NaN
# 169  59.0  46.0   4.0   NaN    NaN   NaN   NaN     NaN
# 170  53.0  60.0  11.0   NaN    NaN   NaN   NaN     NaN
# 172   NaN   NaN   NaN  61.0   59.0  27.0  43.0    58.0
# 174   NaN   NaN   NaN  57.0   56.0  23.0  36.0    76.0
# 175  61.0  53.0   4.0   NaN    NaN   NaN   NaN     NaN
# 176  52.0  51.0  18.0   NaN    NaN   NaN   NaN     NaN
# 177  58.0  52.0   2.0   NaN    NaN   NaN   NaN     NaN
# 180   NaN   NaN   NaN  53.0   53.0  21.0  36.0    82.0
# 186  20.0  49.0  93.0   NaN    NaN   NaN   NaN     NaN
# 187   NaN   NaN   NaN  55.0   58.0  18.0  43.0    69.0
# 188  57.0  45.0   2.0   NaN    NaN   NaN   NaN     NaN

# %% [markdown]
# ## Positions

# %% [markdown]
# ### 1B

# %%
first_base = all_players_owners[all_players_owners['Positions'].str.contains('1B')]
first_base = first_base[ ['Player', 'Positions', 'Team', 'SCORE', 'RANK', 'AVGS', 'BBKOS', 'HRS', 'RBIS', 'RS', 'SBS', 'Owner'] ]

# %%
first_base.head(25)
# Out:
#                 Player       Positions Team  SCORE   RANK  AVGS  BBKOS   HRS  \
# 14    Paul Goldschmidt              1B  STL  384.0   15.0  68.0   68.0  68.0
# 16     Freddie Freeman              1B  ATL  382.0   17.0  84.0   66.0  61.0
# 17       Anthony Rizzo              1B  CHC  379.0   19.5  65.0   79.0  66.0
# 23        Rhys Hoskins           1B,LF  PHI  365.0   24.0  38.0   67.0  85.0
# 27          Joey Votto              1B  CIN  360.0   28.0  72.0   98.0  49.0
# 29      Cody Bellinger           1B,CF  LAD  351.0   30.0  47.0   55.0  73.0
# 37     Whit Merrifield  1B,2B,CF,RF,DH   KC  339.0   38.0  71.0   51.0  29.0
# 39      Matt Carpenter        1B,2B,3B  STL  331.0   40.0  41.0   77.0  66.0
# 43       Daniel Murphy           1B,2B  COL  326.0   43.5  86.0   56.0  49.0
# 47      Carlos Santana           1B,3B  CLE  324.0   47.0  37.0   92.0  54.0
# 56         Travis Shaw        1B,3B,2B  MIL  311.0   59.5  42.0   60.0  66.0
# 65          Jose Abreu           1B,DH  CWS  309.0   64.5  66.0   42.0  61.0
# 70          Joey Gallo     1B,LF,CF,RF  TEX  306.0   71.0  11.0   44.0  95.0
# 71          Matt Olson              1B  OAK  305.0   72.0  34.0   52.0  73.0
# 72   Edwin Encarnacion           1B,DH  SEA  303.0   73.5  32.0   60.0  71.0
# 74         Eric Hosmer              1B   SD  301.0   75.0  56.0   57.0  49.0
# 75       Jesus Aguilar              1B  MIL  300.0   76.5  44.0   43.0  73.0
# 96           Josh Bell              1B  PIT  285.0   96.5  51.0   68.0  41.0
# 97           Max Muncy        1B,2B,3B  LAD  284.0   98.5  37.0   62.0  63.0
# 100      J.T. Realmuto            C,1B  PHI  281.0  102.5  59.0   43.0  51.0
# 108         Ryan Braun           1B,LF  MIL  278.0  110.0  51.0   47.0  49.0
# 113       Justin Smoak           1B,DH  TOR  276.0  114.0  33.0   58.0  63.0
# 122   Jurickson Profar     1B,2B,3B,SS  OAK  272.0  122.5  43.0   61.0  37.0
# 123     Miguel Cabrera           1B,DH  DET  272.0  122.5  60.0   61.0  46.0
# 130        Jake Bauers           1B,LF  CLE  267.0  131.0  31.0   59.0  39.0
#
#      RBIS    RS   SBS                          Owner
# 14   79.0  79.0  22.0           Martin Awaiting Klub
# 16   78.0  75.0  18.0                       Walk Off
# 17   84.0  69.0  16.0              Low hanging fruit
# 23   89.0  75.0  11.0                La Flama Blanca
# 27   66.0  66.0   9.0          Rakuten Golden Eagles
# 29   78.0  71.0  27.0                       Foul_Tip
# 37   50.0  65.0  73.0                 Regular Rubens
# 39   61.0  79.0   7.0                 Regular Rubens
# 43   65.0  61.0   9.0           Martin Awaiting Klub
# 47   70.0  64.0   7.0               Tommy's Shinebox
# 56   72.0  58.0  13.0                  Team Gorgeous
# 65   75.0  61.0   4.0             stroke me strokeme
# 70   78.0  67.0  11.0             stroke me strokeme
# 71   76.0  66.0   4.0                  Team Gorgeous
# 72   78.0  58.0   4.0  MitchMoreland'sBattingAverage
# 74   65.0  61.0  13.0               Tommy's Shinebox
# 75   81.0  59.0   0.0                 Regular Rubens
# 96   61.0  57.0   7.0                            NaN
# 97   60.0  55.0   7.0  MitchMoreland'sBattingAverage
# 100  62.0  55.0  11.0                  Team Gorgeous
# 108  56.0  48.0  27.0                            NaN
# 113  65.0  55.0   2.0                            NaN
# 122  52.0  59.0  20.0                La Flama Blanca
# 123  60.0  45.0   0.0              Low hanging fruit
# 130  56.0  53.0  29.0                            NaN

# %% [markdown]
# ### 2B

# %%
second_base = all_players_owners[all_players_owners['Positions'].str.contains('2B')]
second_base = second_base[ ['Player', 'Positions', 'Team', 'SCORE', 'RANK', 'AVGS', 'BBKOS', 'HRS', 'RBIS', 'RS', 'SBS', 'Owner'] ]

# %%
second_base.head(25)
# Out:
#                 Player       Positions Team  SCORE   RANK   AVGS  BBKOS   HRS  \
# 2         Jose Ramirez           2B,3B  CLE  447.0    3.0   71.0   86.0  71.0
# 10         Jose Altuve              2B  HOU  395.0   10.5  100.0   65.0  39.0
# 31         Javier Baez        2B,3B,SS  CHC  347.0   32.5   63.0   23.0  71.0
# 37     Whit Merrifield  1B,2B,CF,RF,DH   KC  339.0   38.0   71.0   51.0  29.0
# 39      Matt Carpenter        1B,2B,3B  STL  331.0   40.0   41.0   77.0  66.0
# 43       Daniel Murphy           1B,2B  COL  326.0   43.5   86.0   56.0  49.0
# 55        Ozzie Albies              2B  ATL  314.0   56.0   57.0   45.0  46.0
# 56         Travis Shaw        1B,3B,2B  MIL  311.0   59.5   42.0   60.0  66.0
# 63   Adalberto Mondesi           2B,SS   KC  309.0   64.5   39.0   23.0  44.0
# 77     Scooter Gennett              2B  CIN  299.0   78.0   66.0   39.0  51.0
# 78       Robinson Cano              2B  NYM  298.0   79.5   63.0   59.0  49.0
# 85      Gleyber Torres           2B,SS  NYY  297.0   83.5   54.0   45.0  56.0
# 86        Brian Dozier              2B  WSH  296.0   87.0   31.0   57.0  59.0
# 92        Rougned Odor           2B,DH  TEX  291.0   93.0   36.0   37.0  59.0
# 97           Max Muncy        1B,2B,3B  LAD  284.0   98.5   37.0   62.0  63.0
# 114    Cesar Hernandez              2B  PHI  276.0  114.0   51.0   67.0  24.0
# 118    Jonathan Villar           2B,SS  BAL  274.0  118.5   42.0   36.0  34.0
# 122   Jurickson Profar     1B,2B,3B,SS  OAK  272.0  122.5   43.0   61.0  37.0
# 127         Dee Gordon           2B,CF  SEA  269.0  129.0   63.0   35.0   7.0
# 141   Asdrubal Cabrera        2B,3B,SS  TEX  260.0  143.0   58.0   47.0  46.0
# 146       Yoan Moncada              2B  CWS  258.0  147.5   29.0   39.0  46.0
# 150        Ketel Marte           2B,SS  ARI  256.0  150.0   54.0   60.0  27.0
# 151       Chris Taylor     2B,SS,LF,CF  LAD  255.0  153.0   42.0   39.0  37.0
# 159    Jonathan Schoop              2B  MIN  252.0  160.5   48.0   30.0  56.0
# 176       Jason Kipnis        2B,CF,DH  CLE  247.0  177.0   34.0   53.0  39.0
#
#      RBIS    RS   SBS                          Owner
# 2    82.0  84.0  53.0      BC-Mizusawa South Monkeyz
# 10   64.0  78.0  49.0                La Flama Blanca
# 31   81.0  71.0  38.0                  Team Gorgeous
# 37   50.0  65.0  73.0                 Regular Rubens
# 39   61.0  79.0   7.0                 Regular Rubens
# 43   65.0  61.0   9.0           Martin Awaiting Klub
# 55   59.0  71.0  36.0                       Walk Off
# 56   72.0  58.0  13.0                  Team Gorgeous
# 63   51.0  59.0  93.0                       Foul_Tip
# 77   70.0  62.0  11.0  MitchMoreland'sBattingAverage
# 78   68.0  57.0   2.0                       Foul_Tip
# 85   68.0  54.0  20.0  MitchMoreland'sBattingAverage
# 86   63.0  62.0  24.0      BC-Mizusawa South Monkeyz
# 92   64.0  64.0  31.0               Tommy's Shinebox
# 97   60.0  55.0   7.0  MitchMoreland'sBattingAverage
# 114  37.0  61.0  36.0             stroke me strokeme
# 118  37.0  47.0  78.0               Tommy's Shinebox
# 122  52.0  59.0  20.0                La Flama Blanca
# 127  27.0  55.0  82.0                       Foul_Tip
# 141  56.0  49.0   4.0                            NaN
# 146  49.0  62.0  33.0                            NaN
# 150  43.0  54.0  18.0                            NaN
# 151  50.0  60.0  27.0                            NaN
# 159  62.0  52.0   4.0                            NaN
# 176  52.0  51.0  18.0                            NaN

# %% [markdown]
# ### SS

# %%
shortstop = all_players_owners[all_players_owners['Positions'].str.contains('SS')]
shortstop = shortstop[ ['Player', 'Positions', 'Team', 'SCORE', 'RANK', 'AVGS', 'BBKOS', 'HRS', 'RBIS', 'RS', 'SBS', 'Owner'] ]

# %%
shortstop.head(25)
# Out:
#                 Player    Positions Team  SCORE   RANK  AVGS  BBKOS   HRS  \
# 7         Alex Bregman        3B,SS  HOU  398.0    8.0  71.0   80.0  63.0
# 8     Francisco Lindor           SS  CLE  397.0    9.0  69.0   66.0  68.0
# 9          Trea Turner           SS  WSH  395.0   10.5  68.0   52.0  41.0
# 18       Manny Machado        3B,SS   SD  379.0   19.5  70.0   62.0  76.0
# 26        Trevor Story           SS  COL  361.0   26.5  57.0   32.0  78.0
# 31         Javier Baez     2B,3B,SS  CHC  347.0   32.5  63.0   23.0  71.0
# 35     Xander Bogaerts           SS  BOS  342.0   36.0  70.0   57.0  46.0
# 44       Carlos Correa           SS  HOU  325.0   45.0  56.0   60.0  54.0
# 45         Jean Segura           SS  PHI  324.0   47.0  77.0   49.0  29.0
# 63   Adalberto Mondesi        2B,SS   KC  309.0   64.5  39.0   23.0  44.0
# 64        Corey Seager           SS  LAD  309.0   64.5  69.0   56.0  49.0
# 85      Gleyber Torres        2B,SS  NYY  297.0   83.5  54.0   45.0  56.0
# 93         Jose Peraza           SS  CIN  290.0   94.0  67.0   46.0  24.0
# 95   Andrelton Simmons           SS  LAA  285.0   96.5  67.0   61.0  24.0
# 110      Jorge Polanco           SS  MIN  278.0  110.0  57.0   50.0  32.0
# 118    Jonathan Villar        2B,SS  BAL  274.0  118.5  42.0   36.0  34.0
# 121      Marcus Semien           SS  OAK  272.0  122.5  41.0   51.0  39.0
# 122   Jurickson Profar  1B,2B,3B,SS  OAK  272.0  122.5  43.0   61.0  37.0
# 136       Elvis Andrus           SS  TEX  263.0  137.0  57.0   51.0  24.0
# 141   Asdrubal Cabrera     2B,3B,SS  TEX  260.0  143.0  58.0   47.0  46.0
# 144    Eduardo Escobar        3B,SS  ARI  259.0  145.5  46.0   46.0  46.0
# 150        Ketel Marte        2B,SS  ARI  256.0  150.0  54.0   60.0  27.0
# 151       Chris Taylor  2B,SS,LF,CF  LAD  255.0  153.0  42.0   39.0  37.0
# 161       Tim Anderson           SS  CWS  252.0  160.5  39.0   21.0  41.0
# 168       Amed Rosario           SS  NYM  249.0  169.5  47.0   33.0  24.0
#
#      RBIS    RS    SBS                          Owner
# 7    78.0  82.0   24.0           Martin Awaiting Klub
# 8    69.0  85.0   40.0                       Walk Off
# 9    55.0  79.0  100.0           Martin Awaiting Klub
# 18   80.0  69.0   22.0  MitchMoreland'sBattingAverage
# 26   84.0  68.0   42.0                  Team Gorgeous
# 31   81.0  71.0   38.0                  Team Gorgeous
# 35   76.0  71.0   22.0      BC-Mizusawa South Monkeyz
# 44   77.0  67.0   11.0      BC-Mizusawa South Monkeyz
# 45   50.0  72.0   47.0              Low hanging fruit
# 63   51.0  59.0   93.0                       Foul_Tip
# 64   60.0  66.0    9.0             stroke me strokeme
# 85   68.0  54.0   20.0  MitchMoreland'sBattingAverage
# 93   44.0  56.0   53.0             stroke me strokeme
# 95   54.0  52.0   27.0                            NaN
# 110  54.0  56.0   29.0                            NaN
# 118  37.0  47.0   78.0               Tommy's Shinebox
# 121  53.0  59.0   29.0                            NaN
# 122  52.0  59.0   20.0                La Flama Blanca
# 136  47.0  55.0   29.0                            NaN
# 141  56.0  49.0    4.0                            NaN
# 144  61.0  53.0    7.0                            NaN
# 150  43.0  54.0   18.0                            NaN
# 151  50.0  60.0   27.0                            NaN
# 161  49.0  55.0   47.0                            NaN
# 168  42.0  52.0   51.0                            NaN

# %% [markdown]
# ### 3B

# %%
third_base = all_players_owners[all_players_owners['Positions'].str.contains('3B')]
third_base = third_base[ ['Player', 'Positions', 'Team', 'SCORE', 'RANK', 'AVGS', 'BBKOS', 'HRS', 'RBIS', 'RS', 'SBS', 'Owner'] ]

# %%
third_base.head(25)
# Out:
#                     Player    Positions Team  SCORE   RANK  AVGS  BBKOS   HRS  \
# 2             Jose Ramirez        2B,3B  CLE  447.0    3.0  71.0   86.0  71.0
# 5            Nolan Arenado           3B  COL  410.0    6.5  77.0   62.0  88.0
# 7             Alex Bregman        3B,SS  HOU  398.0    8.0  71.0   80.0  63.0
# 18           Manny Machado        3B,SS   SD  379.0   19.5  70.0   62.0  76.0
# 28          Anthony Rendon           3B  WSH  358.0   29.0  77.0   70.0  54.0
# 30             Kris Bryant        3B,RF  CHC  350.0   31.0  62.0   63.0  63.0
# 31             Javier Baez     2B,3B,SS  CHC  347.0   32.5  63.0   23.0  71.0
# 39          Matt Carpenter     1B,2B,3B  STL  331.0   40.0  41.0   77.0  66.0
# 40          Eugenio Suarez           3B  CIN  328.0   41.0  53.0   53.0  71.0
# 47          Carlos Santana        1B,3B  CLE  324.0   47.0  37.0   92.0  54.0
# 56             Travis Shaw     1B,3B,2B  MIL  311.0   59.5  42.0   60.0  66.0
# 57   Vladimir Guerrero Jr.           3B  TOR  311.0   59.5  76.0   59.0  49.0
# 59          Josh Donaldson        3B,DH  ATL  311.0   59.5  47.0   68.0  63.0
# 60           Justin Turner           3B  LAD  311.0   59.5  72.0   66.0  44.0
# 73          Mike Moustakas        3B,DH  MIL  303.0   73.5  45.0   51.0  73.0
# 80               Wil Myers     3B,LF,RF   SD  297.0   83.5  39.0   43.0  56.0
# 81            Matt Chapman           3B  OAK  297.0   83.5  43.0   44.0  63.0
# 88          Miguel Andujar        3B,DH  NYY  295.0   88.5  65.0   40.0  56.0
# 97               Max Muncy     1B,2B,3B  LAD  284.0   98.5  37.0   62.0  63.0
# 99           Rafael Devers           3B  BOS  283.0  100.0  50.0   40.0  59.0
# 122       Jurickson Profar  1B,2B,3B,SS  OAK  272.0  122.5  43.0   61.0  37.0
# 138          Maikel Franco           3B  PHI  262.0  138.5  45.0   51.0  56.0
# 141       Asdrubal Cabrera     2B,3B,SS  TEX  260.0  143.0  58.0   47.0  46.0
# 144        Eduardo Escobar        3B,SS  ARI  259.0  145.5  46.0   46.0  46.0
# 147              Jake Lamb           3B  ARI  258.0  147.5  31.0   54.0  49.0
#
#      RBIS    RS   SBS                          Owner
# 2    82.0  84.0  53.0      BC-Mizusawa South Monkeyz
# 5    97.0  82.0   4.0                       Foul_Tip
# 7    78.0  82.0  24.0           Martin Awaiting Klub
# 18   80.0  69.0  22.0  MitchMoreland'sBattingAverage
# 28   77.0  69.0  11.0             stroke me strokeme
# 30   70.0  79.0  13.0          Rakuten Golden Eagles
# 31   81.0  71.0  38.0                  Team Gorgeous
# 39   61.0  79.0   7.0                 Regular Rubens
# 40   80.0  64.0   7.0              Low hanging fruit
# 47   70.0  64.0   7.0               Tommy's Shinebox
# 56   72.0  58.0  13.0                  Team Gorgeous
# 57   62.0  54.0  11.0              Low hanging fruit
# 59   62.0  62.0   9.0                La Flama Blanca
# 60   61.0  59.0   9.0                 Regular Rubens
# 73   76.0  54.0   4.0               Tommy's Shinebox
# 80   60.0  57.0  42.0      BC-Mizusawa South Monkeyz
# 81   67.0  73.0   7.0                       Walk Off
# 88   70.0  57.0   7.0              Low hanging fruit
# 97   60.0  55.0   7.0  MitchMoreland'sBattingAverage
# 99   66.0  55.0  13.0                       Walk Off
# 122  52.0  59.0  20.0                La Flama Blanca
# 138  64.0  44.0   2.0                            NaN
# 141  56.0  49.0   4.0                            NaN
# 144  61.0  53.0   7.0                            NaN
# 147  61.0  54.0   9.0                            NaN

# %% [markdown]
# ### C

# %%
catcher = all_players_owners[all_players_owners['Positions'].str.contains('^C$|C,', regex=True)]
catcher = catcher[ ['Player', 'Positions', 'Team', 'SCORE', 'RANK', 'AVGS', 'BBKOS', 'HRS', 'RBIS', 'RS', 'SBS', 'Owner'] ]

# %%
catcher.head(25)
# Out:
#                  Player Positions Team  SCORE   RANK  AVGS  BBKOS   HRS  RBIS  \
# 100       J.T. Realmuto      C,1B  PHI  281.0  102.5  59.0   43.0  51.0  62.0
# 119        Gary Sanchez      C,DH  NYY  273.0  120.0  33.0   46.0  68.0  67.0
# 171        Buster Posey      C,1B   SF  248.0  173.0  67.0   67.0  22.0  43.0
# 222     Yasmani Grandal         C  MIL  232.0  221.0  34.0   57.0  51.0  49.0
# 225       Yadier Molina         C  STL  231.0  225.0  52.0   49.0  34.0  50.0
# 251   Willson Contreras         C  CHC  223.0  250.0  44.0   51.0  34.0  48.0
# 311        Wilson Ramos      C,DH  NYM  207.0  314.0  53.0   46.0  37.0  46.0
# 396        Danny Jansen         C  TOR  189.0  396.0  39.0   55.0  27.0  33.0
# 398  Francisco Cervelli         C  PIT  188.0  399.5  44.0   57.0  22.0  33.0
# 431     Tucker Barnhart         C  CIN  179.0  434.5  41.0   57.0  20.0  32.0
# 514        Omar Narvaez         C  SEA  163.0  516.5  46.0   58.0  17.0  22.0
# 516     Jonathan Lucroy         C  LAA  163.0  516.5  40.0   53.0  15.0  30.0
# 531         Mike Zunino         C   TB  161.0  537.0  18.0   25.0  49.0  42.0
# 544   Robinson Chirinos         C  HOU  160.0  544.5  23.0   41.0  37.0  33.0
# 546       Austin Barnes      C,2B  LAD  159.0  551.0  32.0   54.0  17.0  20.0
# 549  Welington Castillo         C  CWS  159.0  551.0  39.0   35.0  32.0  31.0
# 556         Kurt Suzuki         C  WSH  158.0  558.0  46.0   49.0  22.0  26.0
# 619       Austin Hedges         C   SD  147.0  626.0  32.0   37.0  32.0  28.0
# 623       Tyler Flowers         C  ATL  147.0  626.0  36.0   46.0  22.0  25.0
# 637      Chris Iannetta         C  COL  146.0  637.5  31.0   52.0  24.0  23.0
# 652  Willians Astudillo      C,3B  MIN  145.0  648.0  50.0   48.0  17.0  19.0
# 659          John Hicks      C,1B  DET  143.0  663.0  41.0   37.0  22.0  22.0
# 663        Brian McCann         C  ATL  143.0  663.0  30.0   51.0  24.0  23.0
# 666           Yan Gomes         C  WSH  143.0  663.0  35.0   34.0  27.0  28.0
# 670     Francisco Mejia      C,DH   SD  142.0  675.0  38.0   41.0  22.0  23.0
#
#        RS   SBS                          Owner
# 100  55.0  11.0                  Team Gorgeous
# 119  55.0   4.0                La Flama Blanca
# 171  40.0   9.0  MitchMoreland'sBattingAverage
# 222  39.0   2.0           Martin Awaiting Klub
# 225  35.0  11.0                       Walk Off
# 251  37.0   9.0                       Foul_Tip
# 311  25.0   0.0      BC-Mizusawa South Monkeyz
# 396  28.0   7.0                            NaN
# 398  25.0   7.0                            NaN
# 431  25.0   4.0                            NaN
# 514  18.0   2.0                            NaN
# 516  23.0   2.0                            NaN
# 531  27.0   0.0                            NaN
# 544  24.0   2.0                            NaN
# 546  23.0  13.0                            NaN
# 549  20.0   2.0                            NaN
# 556  15.0   0.0                            NaN
# 619  14.0   4.0                            NaN
# 623  18.0   0.0                            NaN
# 637  16.0   0.0                            NaN
# 652   7.0   4.0                            NaN
# 659  17.0   4.0                            NaN
# 663  13.0   2.0                            NaN
# 666  19.0   0.0                            NaN
# 670  16.0   2.0                            NaN

# %% [markdown]
# ### OF

# %%
outfield = all_players_owners[all_players_owners['Positions'].str.contains('OF|LF|RF|CF', regex=True)]
outfield = outfield[ ['Player', 'Positions', 'Team', 'SCORE', 'RANK', 'AVGS', 'BBKOS', 'HRS', 'RBIS', 'RS', 'SBS', 'Owner'] ]

# %%
outfield[:25]
# Out:
#                Player       Positions Team  SCORE  RANK  AVGS  BBKOS    HRS  \
# 0          Mike Trout           CF,DH  LAA  505.0   1.0  86.0  100.0   90.0
# 1        Mookie Betts           CF,RF  BOS  474.0   2.0  91.0   77.0   71.0
# 3       J.D. Martinez        LF,RF,DH  BOS  418.0   4.0  85.0   50.0   93.0
# 4        Bryce Harper           CF,RF  PHI  412.0   5.0  53.0   88.0   80.0
# 6    Christian Yelich        LF,CF,RF  MIL  410.0   6.5  85.0   61.0   63.0
# 11          Juan Soto              LF  WSH  393.0  12.0  72.0   80.0   68.0
# 15        Aaron Judge           RF,DH  NYY  383.0  16.0  51.0   63.0   90.0
# 19       Ronald Acuna           LF,CF  ATL  379.0  19.5  64.0   42.0   71.0
# 20  Giancarlo Stanton        LF,RF,DH  NYY  379.0  19.5  53.0   44.0  100.0
# 21   Charlie Blackmon              CF  COL  376.0  22.0  79.0   51.0   66.0
# 22  Andrew Benintendi           LF,CF  BOS  371.0  23.0  70.0   68.0   41.0
# 23       Rhys Hoskins           1B,LF  PHI  365.0  24.0  38.0   67.0   85.0
# 29     Cody Bellinger           1B,CF  LAD  351.0  30.0  47.0   55.0   73.0
# 30        Kris Bryant           3B,RF  CHC  350.0  31.0  62.0   63.0   63.0
# 33        Khris Davis           LF,DH  OAK  343.0  34.5  34.0   41.0   98.0
# 36    George Springer        CF,RF,DH  HOU  340.0  37.0  55.0   60.0   61.0
# 37    Whit Merrifield  1B,2B,CF,RF,DH   KC  339.0  38.0  71.0   51.0   29.0
# 38     Starling Marte              CF  PIT  338.0  39.0  66.0   40.0   41.0
# 41       Lorenzo Cain              CF  MIL  327.0  42.0  74.0   63.0   29.0
# 42        Yasiel Puig              RF  CIN  326.0  43.5  58.0   53.0   61.0
# 46         Tommy Pham           LF,CF   TB  324.0  47.0  53.0   54.0   51.0
# 48   Andrew McCutchen           LF,RF  PHI  323.0  49.5  47.0   67.0   56.0
# 49      Marcell Ozuna              LF  STL  323.0  49.5  70.0   46.0   63.0
# 51      Mitch Haniger           CF,RF  SEA  319.0  52.0  58.0   51.0   56.0
# 52      Eddie Rosario              LF  MIN  317.0  53.5  66.0   38.0   59.0
#
#      RBIS     RS   SBS                          Owner
# 0    81.0   97.0  51.0  MitchMoreland'sBattingAverage
# 1    77.0  100.0  58.0               Tommy's Shinebox
# 3   100.0   81.0   9.0             stroke me strokeme
# 4    85.0   82.0  24.0                 Regular Rubens
# 6    78.0   85.0  38.0      BC-Mizusawa South Monkeyz
# 11   80.0   77.0  16.0          Rakuten Golden Eagles
# 15   79.0   84.0  16.0                       Foul_Tip
# 19   72.0   79.0  51.0                  Team Gorgeous
# 20   94.0   81.0   7.0               Tommy's Shinebox
# 21   62.0   91.0  27.0                La Flama Blanca
# 22   68.0   82.0  42.0      BC-Mizusawa South Monkeyz
# 23   89.0   75.0  11.0                La Flama Blanca
# 29   78.0   71.0  27.0                       Foul_Tip
# 30   70.0   79.0  13.0          Rakuten Golden Eagles
# 33   95.0   73.0   2.0             stroke me strokeme
# 36   63.0   85.0  16.0           Martin Awaiting Klub
# 37   50.0   65.0  73.0                 Regular Rubens
# 38   54.0   64.0  73.0                       Walk Off
# 41   39.0   69.0  53.0               Tommy's Shinebox
# 42   66.0   57.0  31.0              Low hanging fruit
# 46   55.0   73.0  38.0          Rakuten Golden Eagles
# 48   62.0   67.0  24.0          Rakuten Golden Eagles
# 49   80.0   60.0   4.0             stroke me strokeme
# 51   69.0   67.0  18.0                       Walk Off
# 52   67.0   67.0  20.0                  Team Gorgeous

# %%
outfield[25:50]
# Out:
#                    Player    Positions Team  SCORE   RANK  AVGS  BBKOS   HRS  \
# 54            Aaron Hicks           CF  NYY  315.0   55.0  38.0   73.0  56.0
# 58       Michael Brantley        LF,DH  HOU  311.0   59.5  74.0   64.0  34.0
# 61   Nicholas Castellanos           RF  DET  311.0   59.5  68.0   40.0  59.0
# 62       Michael Conforto     LF,CF,RF  NYM  309.0   64.5  38.0   60.0  68.0
# 67           Justin Upton        LF,DH  LAA  308.0   67.5  40.0   43.0  68.0
# 70             Joey Gallo  1B,LF,CF,RF  TEX  306.0   71.0  11.0   44.0  95.0
# 79          David Peralta           LF  ARI  298.0   79.5  67.0   47.0  54.0
# 80              Wil Myers     3B,LF,RF   SD  297.0   83.5  39.0   43.0  56.0
# 83             David Dahl     LF,CF,RF  COL  297.0   83.5  58.0   34.0  59.0
# 84         Ender Inciarte           CF  ATL  297.0   83.5  64.0   57.0  20.0
# 90           A.J. Pollock           CF  LAD  294.0   90.5  46.0   46.0  49.0
# 98           Nomar Mazara           RF  TEX  284.0   98.5  52.0   47.0  54.0
# 102          Mallex Smith     LF,CF,RF  SEA  281.0  102.5  54.0   49.0  10.0
# 104      Stephen Piscotty           RF  OAK  279.0  106.5  50.0   49.0  51.0
# 108            Ryan Braun        1B,LF  MIL  278.0  110.0  51.0   47.0  49.0
# 111         Victor Robles           RF  WSH  277.0  112.0  54.0   47.0  27.0
# 116         Shin-Soo Choo     LF,RF,DH  TEX  275.0  116.5  44.0   63.0  44.0
# 120        Kyle Schwarber           LF  CHC  272.0  122.5  27.0   58.0  66.0
# 124          Jesse Winker        LF,RF  CIN  271.0  125.5  65.0   73.0  32.0
# 125            Adam Eaton        LF,RF  WSH  271.0  125.5  67.0   59.0  22.0
# 127            Dee Gordon        2B,CF  SEA  269.0  129.0  63.0   35.0   7.0
# 128          Eloy Jimenez        LF,RF  CWS  269.0  129.0  65.0   42.0  54.0
# 130           Jake Bauers        1B,LF  CLE  267.0  131.0  31.0   59.0  39.0
# 131       Corey Dickerson        LF,DH  PIT  266.0  132.5  66.0   37.0  44.0
# 133            Max Kepler        CF,RF  MIN  265.0  134.5  36.0   61.0  46.0
#
#      RBIS    RS   SBS                          Owner
# 54   61.0  65.0  22.0              Low hanging fruit
# 58   58.0  57.0  24.0                 Regular Rubens
# 61   74.0  63.0   7.0  MitchMoreland'sBattingAverage
# 62   72.0  64.0   7.0      BC-Mizusawa South Monkeyz
# 67   74.0  65.0  18.0           Martin Awaiting Klub
# 70   78.0  67.0  11.0             stroke me strokeme
# 79   60.0  59.0  11.0                       Foul_Tip
# 80   60.0  57.0  42.0      BC-Mizusawa South Monkeyz
# 83   67.0  55.0  24.0              Low hanging fruit
# 84   43.0  62.0  51.0          Rakuten Golden Eagles
# 90   55.0  60.0  38.0           Martin Awaiting Klub
# 98   73.0  54.0   4.0                       Walk Off
# 102  30.0  54.0  84.0                 Regular Rubens
# 104  65.0  57.0   7.0  MitchMoreland'sBattingAverage
# 108  56.0  48.0  27.0                            NaN
# 111  42.0  49.0  58.0                            NaN
# 116  47.0  61.0  16.0                            NaN
# 120  58.0  54.0   9.0                            NaN
# 124  48.0  49.0   4.0           Martin Awaiting Klub
# 125  38.0  61.0  24.0                            NaN
# 127  27.0  55.0  82.0                       Foul_Tip
# 128  60.0  46.0   2.0                            NaN
# 130  56.0  53.0  29.0                            NaN
# 131  53.0  53.0  13.0                            NaN
# 133  54.0  55.0  13.0                            NaN

# %%
#outfield[50:75]

# %% [markdown]
# ### SP

# %%
starter = all_players_owners[all_players_owners['Positions'].str.contains('SP')]
starter = starter[ ['Player', 'Positions', 'Team', 'SCORE', 'RANK', 'ERAS', 'WHIPS', 'KS', 'WLS', 'SV+HDS', 'Owner'] ]

# %%
starter[:25]
# Out:
#                    Player Positions Team  SCORE   RANK   ERAS  WHIPS     KS  \
# 12             Chris Sale        SP  BOS  388.0   13.0   97.0   99.0   92.0
# 13           Max Scherzer        SP  WSH  385.0   14.0   92.0  100.0  100.0
# 24           Jacob deGrom        SP  NYM  364.0   25.0  100.0   94.0   91.0
# 25       Justin Verlander        SP  HOU  361.0   26.5   84.0   94.0   90.0
# 32           Corey Kluber        SP  CLE  347.0   32.5   84.0   90.0   80.0
# 50            Gerrit Cole        SP  HOU  322.0   51.0   77.0   79.0   87.0
# 53        Carlos Carrasco        SP  CLE  317.0   53.5   78.0   81.0   79.0
# 66            Blake Snell        SP   TB  308.0   67.5   80.0   71.0   78.0
# 68             Aaron Nola        SP  PHI  307.0   69.5   81.0   79.0   76.0
# 69           Trevor Bauer        SP  CLE  307.0   69.5   76.0   72.0   80.0
# 82          Luis Severino        SP  NYY  297.0   83.5   74.0   76.0   68.0
# 87        Clayton Kershaw        SP  LAD  295.0   88.5   80.0   81.0   55.0
# 91           James Paxton        SP  NYY  293.0   92.0   70.0   73.0   71.0
# 94         Walker Buehler        SP  LAD  286.0   95.0   77.0   74.0   64.0
# 101  Seranthony Dominguez     SP,RP  PHI  281.0  102.5   59.0   57.0   24.0
# 105         Shohei Ohtani     SP,DH  LAA  279.0  106.5    NaN    NaN    NaN
# 107      Noah Syndergaard        SP  NYM  279.0  106.5   77.0   73.0   65.0
# 112        Patrick Corbin        SP  WSH  276.0  114.0   72.0   68.0   72.0
# 126     Stephen Strasburg        SP  WSH  270.0  127.0   70.0   70.0   66.0
# 129         Jack Flaherty        SP  STL  269.0  129.0   69.0   69.0   67.0
# 140        Charlie Morton        SP   TB  261.0  140.5   70.0   65.0   62.0
# 142        Mike Clevinger        SP  CLE  260.0  143.0   65.0   63.0   68.0
# 148          Zack Greinke        SP  ARI  256.0  150.0   66.0   73.0   67.0
# 152         Miles Mikolas        SP  STL  255.0  153.0   68.0   72.0   51.0
# 156           David Price        SP  BOS  253.0  157.0   61.0   66.0   62.0
#
#        WLS  SV+HDS                          Owner
# 12   100.0     0.0          Rakuten Golden Eagles
# 13    93.0     0.0              Low hanging fruit
# 24    79.0     0.0                  Team Gorgeous
# 25    93.0     0.0             stroke me strokeme
# 32    93.0     0.0               Tommy's Shinebox
# 50    79.0     0.0              Low hanging fruit
# 53    79.0     0.0             stroke me strokeme
# 66    79.0     0.0                 Regular Rubens
# 68    71.0     0.0                       Walk Off
# 69    79.0     0.0          Rakuten Golden Eagles
# 82    79.0     0.0                  Team Gorgeous
# 87    79.0     0.0  MitchMoreland'sBattingAverage
# 91    79.0     0.0                  Team Gorgeous
# 94    71.0     0.0                       Walk Off
# 101   43.0    98.0                            NaN
# 105    NaN     NaN                            NaN
# 107   64.0     0.0  MitchMoreland'sBattingAverage
# 112   64.0     0.0               Tommy's Shinebox
# 126   64.0     0.0                La Flama Blanca
# 129   64.0     0.0                 Regular Rubens
# 140   64.0     0.0               Tommy's Shinebox
# 142   64.0     0.0                       Walk Off
# 148   50.0     0.0           Martin Awaiting Klub
# 152   64.0     0.0                  Team Gorgeous
# 156   64.0     0.0                       Foul_Tip

# %%
starter[25:50]
# Out:
#                 Player Positions Team  SCORE   RANK  ERAS  WHIPS    KS   WLS  \
# 163    Masahiro Tanaka        SP  NYY  251.0  164.0  60.0   69.0  58.0  64.0
# 164     Kyle Hendricks        SP  CHC  250.0  166.5  64.0   68.0  54.0  64.0
# 165       Jose Berrios        SP  MIN  250.0  166.5  60.0   65.0  68.0  57.0
# 173          J.A. Happ        SP  NYY  248.0  173.0  60.0   65.0  59.0  64.0
# 178       Chris Archer        SP  PIT  246.0  179.5  63.0   61.0  72.0  50.0
# 182   Mike Foltynewicz        SP  ATL  245.0  182.0  63.0   62.0  63.0  57.0
# 183          Rich Hill        SP  LAD  244.0  185.0  66.0   68.0  53.0  57.0
# 184         Robbie Ray        SP  ARI  244.0  185.0  62.0   56.0  76.0  50.0
# 185    Jameson Taillon        SP  PIT  244.0  185.0  67.0   66.0  61.0  50.0
# 193     German Marquez        SP  COL  242.0  191.5  60.0   60.0  72.0  50.0
# 196       Zack Wheeler        SP  NYM  240.0  197.5  67.0   63.0  60.0  50.0
# 204        Cole Hamels        SP  CHC  237.0  204.5  61.0   59.0  60.0  57.0
# 207      Rick Porcello        SP  BOS  236.0  207.5  54.0   65.0  60.0  57.0
# 223     Dallas Keuchel        SP  NaN  231.0  225.0  67.0   60.0  47.0  57.0
# 224        Kenta Maeda        SP  LAD  231.0  225.0  61.0   63.0  50.0  57.0
# 238       Shane Bieber        SP  CLE  226.0  238.5  59.0   61.0  49.0  57.0
# 239  Eduardo Rodriguez        SP  BOS  226.0  238.5  56.0   58.0  55.0  57.0
# 240      Jose Quintana        SP  CHC  225.0  242.0  59.0   57.0  59.0  50.0
# 241      Andrew Heaney        SP  LAA  225.0  242.0  59.0   66.0  57.0  43.0
# 244      Collin McHugh     RP,SP  HOU  224.0  245.0  57.0   60.0  50.0  57.0
# 246    Carlos Martinez        SP  STL  223.0  250.0  63.0   56.0  47.0  57.0
# 256      Luis Castillo        SP  CIN  222.0  256.0  58.0   63.0  58.0  43.0
# 260         Yu Darvish        SP  CHC  220.0  262.5  58.0   59.0  53.0  50.0
# 267  Madison Bumgarner        SP   SF  219.0  268.0  62.0   65.0  56.0  36.0
# 273     Nathan Eovaldi        SP  BOS  217.0  274.5  58.0   60.0  42.0  57.0
#
#      SV+HDS                      Owner
# 163     0.0                   Foul_Tip
# 164     0.0      Rakuten Golden Eagles
# 165     0.0       Martin Awaiting Klub
# 173     0.0              Team Gorgeous
# 178     0.0       Martin Awaiting Klub
# 182     0.0           Tommy's Shinebox
# 183     0.0             Regular Rubens
# 184     0.0            La Flama Blanca
# 185     0.0       Martin Awaiting Klub
# 193     0.0             Regular Rubens
# 196     0.0  BC-Mizusawa South Monkeyz
# 204     0.0         stroke me strokeme
# 207     0.0            La Flama Blanca
# 223     0.0                        NaN
# 224     0.0                        NaN
# 238     0.0             Regular Rubens
# 239     0.0                        NaN
# 240     0.0                        NaN
# 241     0.0                        NaN
# 244     0.0            La Flama Blanca
# 246     0.0                        NaN
# 256     0.0          Low hanging fruit
# 260     0.0  BC-Mizusawa South Monkeyz
# 267     0.0                        NaN
# 273     0.0                   Walk Off

# %% [markdown]
# ### RP

# %%
relief = all_players_owners[all_players_owners['Positions'].str.contains('RP')]
relief = relief[ ['Player', 'Positions', 'Team', 'SCORE', 'RANK', 'ERAS', 'WHIPS', 'KS', 'WLS', 'SV+HDS', 'Owner'] ]

# %%
relief[:25]
# Out:
#                    Player Positions Team  SCORE   RANK  ERAS  WHIPS    KS  \
# 76             Edwin Diaz        RP  NYM  300.0   76.5  68.0   66.0  32.0
# 89             Josh Hader        RP  MIL  294.0   90.5  67.0   64.0  40.0
# 101  Seranthony Dominguez     SP,RP  PHI  281.0  102.5  59.0   57.0  24.0
# 103         Andrew Miller        RP  STL  281.0  102.5  59.0   57.0  22.0
# 106             Brad Hand        RP  CLE  279.0  106.5  61.0   58.0  28.0
# 109         Kenley Jansen        RP  LAD  278.0  110.0  61.0   64.0  24.0
# 115       Aroldis Chapman        RP  NYY  275.0  116.5  62.0   58.0  28.0
# 117         Blake Treinen        RP  OAK  274.0  118.5  66.0   59.0  24.0
# 132         Adam Ottavino        RP  NYY  266.0  132.5  57.0   53.0  26.0
# 137        Felipe Vazquez        RP  PIT  262.0  138.5  63.0   56.0  25.0
# 139        Sean Doolittle        RP  WSH  261.0  140.5  62.0   63.0  20.0
# 143         Roberto Osuna        RP  HOU  260.0  143.0  58.0   61.0  18.0
# 145         Craig Kimbrel        RP  NaN  259.0  145.5  63.0   60.0  29.0
# 157       Dellin Betances        RP  NYY  252.0  160.5  64.0   59.0  33.0
# 160           Kirby Yates        RP   SD  252.0  160.5  59.0   58.0  26.0
# 172       David Robertson        RP  PHI  248.0  173.0  61.0   59.0  27.0
# 174       Raisel Iglesias        RP  CIN  248.0  173.0  57.0   56.0  23.0
# 180            Wade Davis        RP  COL  245.0  182.0  53.0   53.0  21.0
# 181          Jose Leclerc        RP  TEX  245.0  182.0  58.0   53.0  27.0
# 187        Chris Devenski        RP  HOU  243.0  187.5  55.0   58.0  18.0
# 192          Corey Knebel        RP  MIL  242.0  191.5  61.0   56.0  29.0
# 198          Ryan Brasier        RP  BOS  239.0  199.5  54.0   54.0  13.0
# 200            Cody Allen        RP  LAA  238.0  202.0  52.0   52.0  22.0
# 203             Ken Giles        RP  TOR  237.0  204.5  53.0   55.0  20.0
# 210         Jose Alvarado        RP   TB  235.0  213.0  61.0   53.0  21.0
#
#       WLS  SV+HDS                          Owner
# 76   43.0    91.0                       Foul_Tip
# 89   43.0    80.0                       Walk Off
# 101  43.0    98.0                            NaN
# 103  43.0   100.0                            NaN
# 106  43.0    89.0              Low hanging fruit
# 109  36.0    93.0          Rakuten Golden Eagles
# 115  43.0    84.0  MitchMoreland'sBattingAverage
# 117  43.0    82.0                       Foul_Tip
# 132  43.0    87.0                            NaN
# 137  36.0    82.0          Rakuten Golden Eagles
# 139  43.0    73.0  MitchMoreland'sBattingAverage
# 143  36.0    87.0              Low hanging fruit
# 145  43.0    64.0                  Team Gorgeous
# 157  43.0    53.0                            NaN
# 160  36.0    73.0             stroke me strokeme
# 172  43.0    58.0                            NaN
# 174  36.0    76.0                            NaN
# 180  36.0    82.0                            NaN
# 181  36.0    71.0               Tommy's Shinebox
# 187  43.0    69.0                            NaN
# 192  36.0    60.0                 Regular Rubens
# 198  36.0    82.0                            NaN
# 200  36.0    76.0                            NaN
# 203  36.0    73.0                            NaN
# 210  36.0    64.0                            NaN

# %% [markdown]
# ## My Team

# %%
my_team = all_players_owners[ all_players_owners['Owner'] == 'Tommy\'s Shinebox' ]
my_team
# Out:
#                 Player Positions Team  SCORE   RANK  AVGS  BBKOS    HRS  RBIS  \
# 1         Mookie Betts     CF,RF  BOS  474.0    2.0  91.0   77.0   71.0  77.0
# 20   Giancarlo Stanton  LF,RF,DH  NYY  379.0   19.5  53.0   44.0  100.0  94.0
# 32        Corey Kluber        SP  CLE  347.0   32.5   NaN    NaN    NaN   NaN
# 34         Nelson Cruz        DH  MIN  343.0   34.5  56.0   51.0   83.0  87.0
# 41        Lorenzo Cain        CF  MIL  327.0   42.0  74.0   63.0   29.0  39.0
# 47      Carlos Santana     1B,3B  CLE  324.0   47.0  37.0   92.0   54.0  70.0
# 73      Mike Moustakas     3B,DH  MIL  303.0   73.5  45.0   51.0   73.0  76.0
# 74         Eric Hosmer        1B   SD  301.0   75.0  56.0   57.0   49.0  65.0
# 92        Rougned Odor     2B,DH  TEX  291.0   93.0  36.0   37.0   59.0  64.0
# 112     Patrick Corbin        SP  WSH  276.0  114.0   NaN    NaN    NaN   NaN
# 118    Jonathan Villar     2B,SS  BAL  274.0  118.5  42.0   36.0   34.0  37.0
# 140     Charlie Morton        SP   TB  261.0  140.5   NaN    NaN    NaN   NaN
# 181       Jose Leclerc        RP  TEX  245.0  182.0   NaN    NaN    NaN   NaN
# 182   Mike Foltynewicz        SP  ATL  245.0  182.0   NaN    NaN    NaN   NaN
# 236      Jose Martinez     1B,RF  STL  226.0  238.5  65.0   51.0   29.0  43.0
#
#         RS   SBS  ERAS  WHIPS    KS   WLS  SV+HDS             Owner
# 1    100.0  58.0   NaN    NaN   NaN   NaN     NaN  Tommy's Shinebox
# 20    81.0   7.0   NaN    NaN   NaN   NaN     NaN  Tommy's Shinebox
# 32     NaN   NaN  84.0   90.0  80.0  93.0     0.0  Tommy's Shinebox
# 34    64.0   2.0   NaN    NaN   NaN   NaN     NaN  Tommy's Shinebox
# 41    69.0  53.0   NaN    NaN   NaN   NaN     NaN  Tommy's Shinebox
# 47    64.0   7.0   NaN    NaN   NaN   NaN     NaN  Tommy's Shinebox
# 73    54.0   4.0   NaN    NaN   NaN   NaN     NaN  Tommy's Shinebox
# 74    61.0  13.0   NaN    NaN   NaN   NaN     NaN  Tommy's Shinebox
# 92    64.0  31.0   NaN    NaN   NaN   NaN     NaN  Tommy's Shinebox
# 112    NaN   NaN  72.0   68.0  72.0  64.0     0.0  Tommy's Shinebox
# 118   47.0  78.0   NaN    NaN   NaN   NaN     NaN  Tommy's Shinebox
# 140    NaN   NaN  70.0   65.0  62.0  64.0     0.0  Tommy's Shinebox
# 181    NaN   NaN  58.0   53.0  27.0  36.0    71.0  Tommy's Shinebox
# 182    NaN   NaN  63.0   62.0  63.0  57.0     0.0  Tommy's Shinebox
# 236   34.0   4.0   NaN    NaN   NaN   NaN     NaN  Tommy's Shinebox

# %%
round(my_team[ ['AVGS', 'BBKOS', 'HRS', 'RBIS', 'RS', 'SBS', 'ERAS', 'WHIPS', 'KS', 'WLS', 'SV+HDS'] ].mean())
# Out:
# AVGS      56.0
# BBKOS     56.0
# HRS       58.0
# RBIS      65.0
# RS        64.0
# SBS       26.0
# ERAS      69.0
# WHIPS     68.0
# KS        61.0
# WLS       63.0
# SV+HDS    14.0
# dtype: float64

# %% [markdown]
# ## Roto Analysis

# %%
cols = ['Team', 'Count', 'AVGS', 'BBKOS', 'HRS', 'RBIS', 'RS', 'SBS', 'ERAS', 'WHIPS', 'KS', 'WLS', 'SV+HDS' ]
roto_score = pd.DataFrame(columns = cols)
for team in pd.unique(all_players_owners['Owner'].dropna()):
    roster = all_players_owners[ all_players_owners['Owner'] == team ]
    row = []
    row.append(team)
    row.append(len(roster))
    for stat in ['AVGS', 'BBKOS', 'HRS', 'RBIS', 'RS', 'SBS', 'ERAS', 'WHIPS', 'KS', 'WLS', 'SV+HDS']:
        if roster[stat].isnull().all():
            row.append(0)
        else:
            row.append(round(roster[stat].mean()))
    row = tuple(row)
    rosterdf = pd.DataFrame([row], columns=cols)
    roto_score = roto_score.append(rosterdf, ignore_index=True)

# %%
roto_score
# Out:
#                              Team Count AVGS BBKOS HRS RBIS  RS SBS ERAS  \
# 0   MitchMoreland'sBattingAverage    14   59    58  60   69  62  15   67
# 1                Tommy's Shinebox    15   56    56  58   65  64  26   69
# 2       BC-Mizusawa South Monkeyz    13   54    57  53   66  64  28   59
# 3              stroke me strokeme    13   59    51  62   72  66  15   70
# 4                  Regular Rubens    13   58    63  48   61  65  32   66
# 5                        Foul_Tip    13   56    49  54   62  61  27   64
# 6            Martin Awaiting Klub    13   59    59  54   63  67  26   64
# 7                        Walk Off    14   59    50  54   65  64  24   70
# 8                 La Flama Blanca    12   54    60  57   62  69  20   59
# 9           Rakuten Golden Eagles    12   62    70  51   63  71  25   69
# 10              Low hanging fruit    14   61    56  55   67  60  18   69
# 11                  Team Gorgeous    13   55    41  67   73  66  26   72
#
#    WHIPS  KS WLS SV+HDS
# 0     66  44  53     31
# 1     68  61  63     14
# 2     59  57  50      0
# 3     73  64  66     18
# 4     64  58  57     10
# 5     65  44  54     43
# 6     66  67  52      0
# 7     68  58  61     16
# 8     61  58  54      0
# 9     69  56  58     29
# 10    72  58  59     35
# 11    73  62  68     11

# %%
cols = ['AVGS', 'BBKOS', 'HRS', 'RBIS', 'RS', 'SBS', 'ERAS', 'WHIPS', 'KS', 'WLS', 'SV+HDS' ]
for col in cols:
    roto_score[col] = roto_score[col].rank(method='average', na_option='keep', ascending=True, pct=False)
roto_score['Score'] = roto_score[cols].sum(axis=1)

# %%
roto_score.sort_values(['Score'], ascending=False)
# Out:
#                              Team Count  AVGS  BBKOS   HRS  RBIS    RS   SBS  \
# 3              stroke me strokeme    13   8.5    4.0  11.0  11.0   8.5   1.5
# 11                  Team Gorgeous    13   3.0    1.0  12.0  12.0   8.5   8.0
# 9           Rakuten Golden Eagles    12  12.0   12.0   2.0   4.5  12.0   6.0
# 10              Low hanging fruit    14  11.0    5.5   7.0   9.0   1.0   3.0
# 1                Tommy's Shinebox    15   4.5    5.5   9.0   6.5   5.0   8.0
# 7                        Walk Off    14   8.5    3.0   5.0   6.5   5.0   5.0
# 6            Martin Awaiting Klub    13   8.5    9.0   5.0   4.5  10.0   8.0
# 0   MitchMoreland'sBattingAverage    14   8.5    8.0  10.0  10.0   3.0   1.5
# 4                  Regular Rubens    13   6.0   11.0   1.0   1.0   7.0  12.0
# 8                 La Flama Blanca    12   1.5   10.0   8.0   2.5  11.0   4.0
# 5                        Foul_Tip    13   4.5    2.0   5.0   2.5   2.0  10.0
# 2       BC-Mizusawa South Monkeyz    13   1.5    7.0   3.0   8.0   5.0  11.0
#
#     ERAS  WHIPS    KS   WLS  SV+HDS  Score
# 3   10.5   11.5  11.0  11.0     8.0   96.5
# 11  12.0   11.5  10.0  12.0     5.0   95.0
# 9    8.0    9.0   3.0   7.0     9.0   84.5
# 10   8.0   10.0   6.5   8.0    11.0   80.0
# 1    8.0    7.5   9.0  10.0     6.0   79.0
# 7   10.5    7.5   6.5   9.0     7.0   73.5
# 6    3.5    5.5  12.0   2.0     2.0   70.0
# 0    6.0    5.5   1.5   3.0    10.0   67.0
# 4    5.0    3.0   6.5   6.0     4.0   62.5
# 8    1.5    2.0   6.5   4.5     2.0   53.5
# 5    3.5    4.0   1.5   4.5    12.0   51.5
# 2    1.5    1.0   4.0   1.0     2.0   45.0

# %%
roto_score_adj = roto_score
del roto_score_adj['SV+HDS']
cols = ['AVGS', 'BBKOS', 'HRS', 'RBIS', 'RS', 'SBS', 'ERAS', 'WHIPS', 'KS', 'WLS' ]
roto_score_adj['Score'] = roto_score[cols].sum(axis=1)

# %%
roto_score_adj.sort_values(['Score'], ascending=False)
# Out:
#                              Team Count  AVGS  BBKOS   HRS  RBIS    RS   SBS  \
# 11                  Team Gorgeous    13   3.0    1.0  12.0  12.0   8.5   8.0
# 3              stroke me strokeme    13   8.5    4.0  11.0  11.0   8.5   1.5
# 9           Rakuten Golden Eagles    12  12.0   12.0   2.0   4.5  12.0   6.0
# 1                Tommy's Shinebox    15   4.5    5.5   9.0   6.5   5.0   8.0
# 10              Low hanging fruit    14  11.0    5.5   7.0   9.0   1.0   3.0
# 6            Martin Awaiting Klub    13   8.5    9.0   5.0   4.5  10.0   8.0
# 7                        Walk Off    14   8.5    3.0   5.0   6.5   5.0   5.0
# 4                  Regular Rubens    13   6.0   11.0   1.0   1.0   7.0  12.0
# 0   MitchMoreland'sBattingAverage    14   8.5    8.0  10.0  10.0   3.0   1.5
# 8                 La Flama Blanca    12   1.5   10.0   8.0   2.5  11.0   4.0
# 2       BC-Mizusawa South Monkeyz    13   1.5    7.0   3.0   8.0   5.0  11.0
# 5                        Foul_Tip    13   4.5    2.0   5.0   2.5   2.0  10.0
#
#     ERAS  WHIPS    KS   WLS  Score
# 11  12.0   11.5  10.0  12.0   90.0
# 3   10.5   11.5  11.0  11.0   88.5
# 9    8.0    9.0   3.0   7.0   75.5
# 1    8.0    7.5   9.0  10.0   73.0
# 10   8.0   10.0   6.5   8.0   69.0
# 6    3.5    5.5  12.0   2.0   68.0
# 7   10.5    7.5   6.5   9.0   66.5
# 4    5.0    3.0   6.5   6.0   58.5
# 0    6.0    5.5   1.5   3.0   57.0
# 8    1.5    2.0   6.5   4.5   51.5
# 2    1.5    1.0   4.0   1.0   43.0
# 5    3.5    4.0   1.5   4.5   39.5
